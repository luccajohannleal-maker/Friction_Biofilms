# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc
from scipy.stats import ttest_ind


data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"

#tests
file = data_loc+"FreeGrow\\stress\\Lambda1\\repeat0"
files = [data_loc+"FreeGrow\\stress\\Lambda1\\repeat0",data_loc+"FreeGrow\\stress\\Lambda1_5\\repeat0",data_loc+"FreeGrow\\stress\\Lambda5\\repeat0",data_loc+"FreeGrow\\stress\\Lambda10\\repeat0"]
free_stress = [data_loc+"FreeGrow\\stress\\Lambda1\\repeat0",data_loc+"FreeGrow\\stress\\Lambda1_5\\repeat0",data_loc+"FreeGrow\\stress\\Lambda5\\repeat0",data_loc+"FreeGrow\\stress\\Lambda10\\repeat0"]
GR_files = [data_loc+"GR_vary\\GR1",data_loc+"GR_vary\\GR3",data_loc+"FreeGrow\\Lambda10\\repeat0"]


#free growing repeats
Free0_8 = [data_loc+"FreeGrow\\Lambda0_8\\repeat0"]

Free1 = pfunc.repeat_files(data_loc+"FreeGrow\\Lambda1",5)+ pfunc.repeat_files(data_loc+"FreeGrow\\stress\\Lambda1",3)

Free1_5 = [data_loc+"FreeGrow\\stress\\Lambda1_5\\repeat0",data_loc+"FreeGrow\\Lambda1_5\\repeat0"]

Free5 = pfunc.repeat_files(data_loc+"FreeGrow\\Lambda5",5)+ pfunc.repeat_files(data_loc+"FreeGrow\\stress\\Lambda5",4)

Free10 = pfunc.repeat_files(data_loc+"FreeGrow\\Lambda10",1)+pfunc.repeat_files(data_loc+"FreeGrow\\stress\\Lambda10",4)


repeats_lambda= Free1+Free1_5+Free5+Free10
av_repeats_lambda = [Free1,Free1_5,Free5,Free10]


#GR = 3 repeats
repeatGR3_L1 = pfunc.repeat_files(data_loc+"FreeGrow\\stress\\GR3\\Lambda1",7)
repeatGR3_L5 = pfunc.repeat_files(data_loc+"FreeGrow\\stress\\GR3\\Lambda5",7)

GR3_L10_nostress= [data_loc+"GR_vary\\GR3"]
repeatGR3_L10 = GR3_L10_nostress + [data_loc+"FreeGrow\\stress\\GR3\\Lambda10\\repeat0"]

repeatGR3 = repeatGR3_L1 + repeatGR3_L5 + repeatGR3_L10
repeatGR3_av = [repeatGR3_L1,repeatGR3_L5]


"""test = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\FreeGrow\\Lambda1\\repeat4\\biofilm_00080.dat"
Aplot.make_animation(file)"""

#Aplot.plot_t_doub_Lambda_av(repeatGR3_av, lines=True)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\DistributionFunctions.py:27: FutureWarning: This function has no longer any effect, and will be removed in a future release. Starting with Shapely 2.0, equivalent speedups are always available
#   shapely.speedups.enable()
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:59: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log2(R_g) =({round(params_tot[0],3)}+-{round(err_tot[0],3)}) + t/({round(params_tot[1],3)}+-{round(err_tot[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:68: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log_2 N(t) =({round(params_Lambda1[1],3)}+-{round(err_Lambda1[1],3)}) + t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:75: SyntaxWarning: invalid escape sequence '\L'
# ...

# %%
Aplot.average_Rg_time(av_repeats_lambda)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:1141: RuntimeWarning: invalid value encountered in divide
#   std_L1 =np.nanstd(L1_count, axis=0)/(avg_L1*np.log(2)*np.sqrt(L1_count.shape[0]))
# Behaviour for Lambda=1: log_2 Rg(t) =(0.975+-0.019) + t/(1.794+-0.012)
# Behaviour for Lambda=1.5: log_2 Rg(t) =(0.982+-0.024) + t/(1.865+-0.018)
# Behaviour for Lambda=5: log_2 Rg(t) =(0.954+-0.011) + t/(1.898+-0.008)
# Behaviour for Lambda=10: log_2 Rg(t) =(1.061+-0.013) + t/(1.935+-0.011)
# Saved average growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_Rg.pdf

# %%
Aplot.plot_Rg_over_time(repeats_lambda)
# Out:
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.572+-0.05) + t/(1.725+-0.039)
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:60: RuntimeWarning: divide by zero encountered in log2
#   plt.plot(time_steps, np.log2(Rg_tot), '.', markersize=6, color=dfunc.colour_Lambda(Lambdas[0]))#, label=" Counts $\Lambda = 1$")
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.622+-0.048) + t/(1.757+-0.036)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.586+-0.042) + t/(1.751+-0.026)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.685+-0.042) + t/(1.723+-0.024)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.793+-0.049) + t/(1.726+-0.029)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.664+-0.044) + t/(1.703+-0.027)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.537+-0.04) + t/(1.794+-0.028)
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.55+-0.039) + t/(1.784+-0.027)
# Behaviour for $\Lambda=1.5$: $log2(R_g) =(0.617+-0.042) + t/(1.772+-0.027)
# ...

# %%
Aplot.COM_Ncells_long(repeats_lambda,log=True)
# Out:
# Saved surface fraction plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.average_COM_time(av_repeats_lambda)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:52: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log2(R_g) =({round(params_tot[0],3)}+-{round(err_tot[0],3)}) + t/({round(params_tot[1],3)}+-{round(err_tot[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:61: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log_2 N(t) =({round(params_Lambda1[1],3)}+-{round(err_Lambda1[1],3)}) + t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:68: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[1]}$: $log_2 N(t) =({round(params_Lambda2[1],3)}+-{round(err_Lambda2[1],3)}) + t/({round(params_Lambda2[0],3)}+-{round(err_Lambda2[0],3)})")
# ...

# %%
Aplot.COM_Ncells_parameter_dist(repeats_lambda)
# Out:
# Scaling Lambda=0.8: Rcom(N) = (0.8138+-nan)*N^(-0.1704+-nan)
# Scaling Lambda=1.0: Rcom(N) = (1.047+-0.3382)*N^(0.0046+-0.0729)
# Scaling Lambda=1.5: Rcom(N) = (0.7742+-0.2863)*N^(0.0092+-0.1183)
# Scaling Lambda=5.0: Rcom(N) = (394.1172+-393.4114)*N^(-0.1357+-0.1697)
# Scaling Lambda=10.0: Rcom(N) = (0.8528+-0.386)*N^(-0.0169+-0.1136)
# Saved surface fraction plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.PerimArea_Ncells(repeats_lambda)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\Lambda0_8\repeat0
# Lambda = 0.8, A(N) = (6.311352182886463+-0.1858896329179385)*N^(0.9740411032530445+-0.005194789170826764)
# Lambda = 0.8, P(N) = (23.253773742187807+-1.5363520030601796)*N^(0.443077602005908+-0.012773907930378811)
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\Lambda1\repeat0
# Lambda = 1, A(N) = (6.27914004805919+-0.16161792212345072)*N^(0.9720470226227038+-0.004515490957293143)
# Lambda = 1, P(N) = (25.76503908634632+-1.4030455207682275)*N^(0.4434622086520576+-0.01047647585653373)
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\Lambda1\repeat1
# Lambda = 1, A(N) = (6.3408898528323405+-0.1268002592510325)*N^(0.9719682760078869+-0.0032086971346388434)
# Lambda = 1, P(N) = (28.65902302226472+-1.8993988689143035)*N^(0.41987235982497506+-0.01168344563085667)
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\Lambda1\repeat2
# ...

# %%
Aplot.estimate_PerimArea_growth_mean_exp("Area_Perimeter_exponents_FreeGrowth")
# Out:
# Scaling Lambda=0.8: A(N) = (6.3114+-nan)*N^(0.974+-nan)
# Scaling Lambda=0.8: P(N) = (23.2538+-nan)*N^(0.4431+-nan)
# Scaling Lambda=1.0: A(N) = (7.5112+-0.3808)*N^(0.946+-0.0077)
# Scaling Lambda=1.0: P(N) = (27.567+-1.0299)*N^(0.4294+-0.0053)
# Scaling Lambda=1.5: A(N) = (7.5064+-0.5387)*N^(0.9415+-0.0114)
# Scaling Lambda=1.5: P(N) = (24.0297+-1.9141)*N^(0.4508+-0.0195)
# Scaling Lambda=5.0: A(N) = (10.245+-0.4296)*N^(0.8818+-0.007)
# Scaling Lambda=5.0: P(N) = (26.811+-0.8806)*N^(0.4147+-0.0054)
# Scaling Lambda=10.0: A(N) = (9.6202+-1.0543)*N^(0.8847+-0.0195)
# Scaling Lambda=10.0: P(N) = (26.278+-1.6059)*N^(0.4151+-0.0107)
# Scaling total: A(N) = (8.8687964+-0.38532337795756266)*N^(0.91138512+-0.008316781942818992)
# Scaling total: P(N) = (8.8687964+-0.38532337795756266)*N^(0.4235252+-0.004064638329134176)

# %% [markdown]
# # Initial test to show that the functions work

# %%
Aplot.plot_cells_grid(files[1],num_snapshots=6)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_growth_rate(file)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.189+-0.037) + t/(0.723+-0.004)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_counts_over_time(file)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
Aplot.plot_Rg_over_time(file)
# Out:
# Behaviour for $\Lambda=1$: $log_2(R_g) =(0.759+-0.056) + t/(0.782+-0.007)
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:38: RuntimeWarning: divide by zero encountered in log2
#   plt.plot(time_steps, np.log2(Rg_tot), '.', markersize=6, color=dfunc.colour_Lambda(Lambdas[0]))#, label=" Counts $\Lambda = 1$")
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
Aplot.plot_shape_asphericity(files[1])
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.plot_stress_t(file)
# Out:
# Saved stress over time plot to: C:\Users\lucca\Desktop\GeneratedOutput\stress_colony_time.pdf

# %%
Aplot.plot_stress_dist(file)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda1\repeat0\biofilm_00081.dat
# 238.34219097759424
# 391.03963993436776
# 491.59637915672243
# 589.9872879986483
# 653.1385764139185
# 687.0291114647181
# 763.5142434820715
# 779.4530133369169
# 538.8970217026626
# Saved stress over distance plot to: C:\Users\lucca\Desktop\GeneratedOutput\stress_colony_distance.pdf

# %%
Aplot.plot_pressure_t(file)
# Out:
# Saved pressure plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_time.pdf

# %%
Aplot.plot_pressure_dist(file)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda1\repeat0\biofilm_00081.dat
# Saved pressure vs distance plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_distance.pdf

# %% [markdown]
# # Comparison between various $\Lambda$'s

# %%
Aplot.plot_cells_grid(files, num_snapshots=6)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_growth_rate(files)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.189+-0.037) + t/(0.723+-0.004)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.073+-0.03) + t/(0.748+-0.003)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.095+-0.039) + t/(0.752+-0.005)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(-0.103+-0.028) + t/(0.726+-0.003)
# Behaviour for $\Lambda=0.8$: $log_2 N(t) =(-0.137+-0.038) + t/(0.748+-0.005)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_Rg_over_time(files)
# Out:
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.664+-0.044) + t/(1.703+-0.027)
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:53: RuntimeWarning: divide by zero encountered in log2
#   plt.plot(time_steps, np.log2(Rg_tot), '.', markersize=6, color=dfunc.colour_Lambda(Lambdas[0]))#, label=" Counts $\Lambda = 1$")
# Behaviour for $\Lambda=1.5$: $log2(R_g) =(0.617+-0.042) + t/(1.772+-0.027)
# Behaviour for $\Lambda=5$: $log2(R_g) =(0.535+-0.038) + t/(1.803+-0.025)
# Behaviour for $\Lambda=10$: $log2(R_g) =(0.612+-0.04) + t/(1.807+-0.028)
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
Aplot.plot_shape_asphericity(files)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %% [markdown]
# # Repeats for Free Growing comparison $\Lambda = 1$ and $\Lambda = 5$, 8 repeats each

# %%
Aplot.plot_growth_rate(repeats_lambda)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.157+-0.042) + t/(0.722+-0.006)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.096+-0.031) + t/(0.742+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.105+-0.033) + t/(0.752+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.05+-0.035) + t/(0.721+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.294+-0.034) + t/(0.725+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.189+-0.037) + t/(0.723+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.002+-0.03) + t/(0.77+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.148+-0.039) + t/(0.753+-0.005)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.073+-0.03) + t/(0.748+-0.003)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.066+-0.037) + t/(0.754+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.251+-0.035) + t/(0.742+-0.004)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.031+-0.026) + t/(0.737+-0.003)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.116+-0.037) + t/(0.759+-0.004)
# ...

# %% [markdown]
# Run a Student t-test to see the probability that the doubling times have the same expected values. In this test, we assume that the two different sets of doubling times have the same variance.

# %%
tdoub_Lambda1_linear = [0.722,0.742,0.752,0.721,0.725,0.723,0.77,0.753]
tdoub_Lambda5_linear = [0.743,0.737,0.762,0.793,0.751,0.727,0.752,0.744,0.663]

tdoub_Lambda1_exp = [0.734,0.736,0.741,0.724,0.711,0.716]
tdoub_Lambda5_exp = [0.757,0.739,0.763,0.751,0.788,0.754]

results = ttest_ind(tdoub_Lambda1_linear,tdoub_Lambda5_linear) #assuming they have same variation
print(f'the results for the t-test are: t-statistic = {round(results[0],4)}, pval = {round(results[1],4)}')
# Out:
# the results for the t-test are: t-statistic = -0.2055, pval = 0.8399

# %%
Aplot.average_growth_time(av_repeats_lambda)
# Out:
# Behaviour for Lambda=1: log_2 N(t) =(0.043+-0.021) + t/(0.731+-0.002)
# Behaviour for Lambda=1.5: log_2 N(t) =(0.061+-0.027) + t/(0.749+-0.003)
# Behaviour for Lambda=5: log_2 N(t) =(0.002+-0.02) + t/(0.75+-0.002)
# Behaviour for Lambda=10: log_2 N(t) =(0.108+-0.024) + t/(0.737+-0.003)
# Saved average growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_GR.pdf

# %%
Aplot.average_Rg_time(av_repeats_lambda)
# Out:
# 0
# []
# 1
# [[np.int64(1)]]
# 2
# [[np.int64(1)], [np.int64(1)]]
# 3
# [[np.int64(1)], [np.int64(1)], [np.int64(1)]]
# 4
# [[np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)]]
# 5
# [[np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)]]
# 6
# [[np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)]]
# 7
# [[np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)], [np.int64(1)]]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:1134: RuntimeWarning: Mean of empty slice
#   avg_L1 = np.nanmean(L1_count, axis=0)
# C:\Users\lucca\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:2053: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:296: SyntaxWarning: invalid escape sequence '\L'
# ...

# %%
Aplot.average_asphericity_time(av_repeats_lambda)
# Out:
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_shape_asphericity(repeats_lambda)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.plot_COM_time(repeats_lambda)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:280: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:308: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:336: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:390: SyntaxWarning: invalid escape sequence '\L'
# ...

# %% [markdown]
# # Test the effect on Growth rate in different simulations. Theoretical predictions on the doubling time still agree with these results

# %%
#growth rate tests
Aplot.plot_growth_rate(GR_files)
# Out:
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.011+-0.071) + t/(4.499+-0.417)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(-0.015+-0.033) + t/(1.242+-0.011)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.223+-0.043) + t/(0.749+-0.007)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %% [markdown]
# # SIMULATIONS RERUN slower growth: GR = 3
# Since the t-test provided an interesting result, where the means seem to be drawn from different distributions, we decided to run some other tests to correct this behaviour that one bacteria may have an unnecessary advantage by growing faster. To do this, we developed simulations with a lower growth rate (GR3 while previously we had GR5) and below we plot the results

# %%
Aplot.plot_cells_grid(repeatGR3)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_growth_rate(repeatGR3)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.118+-0.035) + t/(1.259+-0.01)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.407+-0.046) + t/(1.319+-0.011)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.11+-0.029) + t/(1.214+-0.007)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.134+-0.033) + t/(1.177+-0.007)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.109+-0.073) + t/(1.28+-0.043)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.218+-0.033) + t/(1.296+-0.007)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.073+-0.028) + t/(1.181+-0.006)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.018+-0.031) + t/(1.272+-0.009)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.232+-0.03) + t/(1.247+-0.007)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.356+-0.04) + t/(1.24+-0.009)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.015+-0.024) + t/(1.225+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.117+-0.027) + t/(1.187+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.112+-0.027) + t/(1.247+-0.006)
# ...

# %% [markdown]
# t-test for the repeats of $\Lambda = 1$ and $\Lambda = 5$ for the GR = 3 displayed above!

# %%
tdoub_Lambda1_linear = [[1.26,1.32,1.21,1.18,1.28,1.296,1.18],[1.21,1.414,1.194,1.134,1.226]] 
tdoub_Lambda5_linear = [[1.272,1.247,1.24,1.225,1.187,1.247,1.304],[1.268,1.294,1.312,1.232,1.322]] 

results = ttest_ind(tdoub_Lambda1_linear[0],tdoub_Lambda5_linear[0]) #assuming they have same variation
print(f'the results for the t-test are: t-statistic = {round(results[0],4)}, pval = {round(results[1],4)}')
# Out:
# the results for the t-test are: t-statistic = 0.0224, pval = 0.9825

# %%
Aplot.average_growth_time(repeatGR3_av)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.131+-0.033) + t/(1.28+-0.007)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.087+-0.019) + t/(1.234+-0.004)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.006+-0.021) + t/(1.239+-0.005)
# Saved average growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_GR.pdf

# %%
Aplot.plot_Rg_over_time(repeatGR3)

# %%
Aplot.average_asphericity_time(repeatGR3_av)
# Out:
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %% [markdown]
# # Time comparisons
# First one is all GR5 values shown prior, the second graph corresponds to all GR3 values.

# %%
Aplot.plot_t_doub_Lambda_av(av_repeats_lambda)
# Out:
# Saved tdoub vs lambda plot to: C:\Users\lucca\Desktop\GeneratedOutput\tdoub_lambda.pdf

# %%
Aplot.plot_t_doub_Lambda_av(repeatGR3_av)
# Out:
# Saved tdoub vs lambda plot to: C:\Users\lucca\Desktop\GeneratedOutput\tdoub_lambda.pdf

# %% [markdown]
# All different $t_{doub}$ calculated for the repeats considered so far.

# %%
Aplot.plot_t_doub_Lambda_av(av_repeats_lambda+repeatGR3_av, lines=False)
# Out:
# Saved tdoub vs lambda plot to: C:\Users\lucca\Desktop\GeneratedOutput\tdoub_lambda.pdf

# %% [markdown]
# # Stress analysis GR3

# %%
Aplot.plot_stress_dist(repeatGR3)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat0\biofilm_00100.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat1\biofilm_00120.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat2\biofilm_00115.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat3\biofilm_00108.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat4\biofilm_00048.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\GR3\Lambda1\repeat5\biofilm_00130.dat
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:305: RuntimeWarning: Mean of empty slice.
#   stress[1,i] = par_stress[np.where((d_cells>=stress[0,i]) & (d_cells<=stress[0,i+1]))].mean()
# ...

# %%
#Aplot.plot_stress_t(repeatGR3)

# %% [markdown]
# # STRESS COMPARISON - GR = 5

# %%
#stress comparison
Aplot.plot_stress_t(free_stress)
# Out:
# Saved stress over time plot to: C:\Users\lucca\Desktop\GeneratedOutput\stress_colony_time.pdf

# %%
Aplot.plot_pressure_dist(free_stress)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda1\repeat0\biofilm_00081.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda1_5\repeat0\biofilm_00084.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda5\repeat0\biofilm_00084.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\FreeGrow\stress\Lambda10\repeat0\biofilm_00082.dat
# Saved pressure vs distance plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_distance.pdf

# %%
Aplot.plot_growth_rate(free_stress)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.189+-0.037) + t/(0.723+-0.004)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.073+-0.03) + t/(0.748+-0.003)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.095+-0.039) + t/(0.752+-0.005)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(-0.103+-0.028) + t/(0.726+-0.003)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_Rg_over_time(free_stress)
# Out:
# Behaviour for $\Lambda=1$: $log2(R_g) =(0.664+-0.044) + t/(1.703+-0.027)
# Behaviour for $\Lambda=1.5$: $log2(R_g) =(0.617+-0.042) + t/(1.772+-0.027)
# Behaviour for $\Lambda=5$: $log2(R_g) =(0.535+-0.038) + t/(1.803+-0.025)
# Behaviour for $\Lambda=10$: $log2(R_g) =(0.612+-0.04) + t/(1.807+-0.028)
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
Aplot.plot_shape_asphericity(free_stress)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:359: RuntimeWarning: invalid value encountered in scalar divide
#   asph1.append((eigenv[0]-eigenv[1])**2 /((eigenv[0]+eigenv[1])**2))
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.plot_Rg_over_time(Free10)
# Out:
# Behaviour for $\Lambda=10$: $log_2(R_g) =(0.77+-0.076) + t/(0.819+-0.015)
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:36: RuntimeWarning: divide by zero encountered in log2
#   plt.plot(time_steps, np.log2(Rg_tot), '.', markersize=6, color=dfunc.colour_Lambda(Lambdas[0]))#, label=" Counts $\Lambda = 1$")
# Behaviour for $\Lambda=10$: $log_2(R_g) =(0.56+-0.044) + t/(0.805+-0.006)
# Behaviour for $\Lambda=10$: $log_2(R_g) =(0.662+-0.056) + t/(0.818+-0.008)
# Behaviour for $\Lambda=10$: $log_2(R_g) =(0.731+-0.065) + t/(0.785+-0.01)
# Behaviour for $\Lambda=10$: $log_2(R_g) =(0.743+-0.061) + t/(0.804+-0.009)
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf
