# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc
from scipy.stats import ttest_ind


data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"

#control interactions
control_interactions = pfunc.repeat_files(data_loc+"Interacting_colonies\\stress\\Lambda1AND1",5)
control_10 = [data_loc+"Interacting_colonies\\stress\\Lambda10AND10\\repeat0"]

#Lambda 1 and 1.5
interacting1_5_stress = pfunc.repeat_files(data_loc+"Interacting_colonies\\stress\\Lambda1AND1_5",3)
interacting1_5 = pfunc.repeat_files(data_loc+"Interacting_colonies\\Lambda1AND1_5",2) + interacting1_5_stress

#Lambda 1 and 5
interacting5_stress = pfunc.repeat_files(data_loc+"Interacting_colonies\\stress\\Lambda1AND5",4)
interacting5 = interacting5_stress +[data_loc+"Interacting_colonies\\Lambda1AND5\\GR5\\repeat0"]

#Lambda 1 and 10
interacting10 = pfunc.repeat_files(data_loc+"Interacting_colonies\\stress\\Lambda1AND10",5)

#all of them for comparison
interactions_compare_av = [control_interactions,interacting1_5,interacting5,interacting10]
interactions_compare = control_interactions+interacting1_5+interacting5+interacting10


#Growth rate = 3
interacting5_GR3 = [data_loc+"Interacting_colonies\\Lambda1AND5\\GR3_repeat1",data_loc+"Interacting_colonies\\stress\\GR3_Lambda1AND5\\repeat1"]
interacting10_GR3 = [data_loc+"Interacting_colonies\\stress\\GR3_Lambda1AND10\\repeat0"]

interacting_GR3= interacting10_GR3 + interacting5_GR3
interacting_GR3_av = [interacting10_GR3, interacting5_GR3]
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:29: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[Lambdas != 1.0][0]}$: $log_2(R_g) = ({round(params[0],3)}+-{round(err[0],3)}) + t/({round(params[1],3)}+-{round(err[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:36: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log_2(R_g) =({round(params_tot[0],3)}+-{round(err_tot[0],3)}) + t/({round(params_tot[1],3)}+-{round(err_tot[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:46: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda=1$: $log_2 N(t) =({round(params_Lambda1[1],3)}+-{round(err_Lambda1[1],3)}) + t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:53: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[Lambdas != 1.0][0]}$: $log_2 N(t) =({round(params_Lambdanot1[1],3)}+-{round(err_Lambdanot1[1],3)}) + t/({round(params_Lambdanot1[0],3)}+-{round(err_Lambdanot1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:65: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda = 1$: $N(t) = 2^t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:72: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[Lambdas != 1.0][0]}$: $N(t) = 2^t/({round(params_Lambdanot1[0],3)}+-{round(err_Lambdanot1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:105: SyntaxWarning: invalid escape sequence '\L'
#   print("OBS: ONLY ONE $\LAMBDA$, CANNOT CALCULATE THE DIFFERENCE")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:395: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambda}$: $log_2 N(t) =({round(params_Lambda1[1],3)}+-{round(err_Lambda1[1],3)}) + t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:404: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambda}$: $log_2 N(t) =({round(params_Lambdanot1[1],3)}+-{round(err_Lambdanot1[1],3)}) + t/({round(params_Lambdanot1[0],3)}+-{round(err_Lambdanot1[0],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:641: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Interacting colonies!
#
# First, we show the control case, where $\Lambda = 1$ and $\Lambda = 1.001$. The value was not set to be exactly equal to 1, as we use the value of $\Lambda$ to differentiate between the two colonies.

# %%
Aplot.plot_cells_grid(control_interactions)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_COM_time(control_interactions)
# Out:
# Saved COM movement plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.average_COM_time([control_interactions])
# Out:
# Saved average xCOM plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_xCOM.pdf

# %%
Aplot.plot_growth_rate(control_interactions)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.195+-0.041) + t/(0.766+-0.005)
# Behaviour for $\Lambda=1.001$: $log_2 N(t) =(-0.02+-0.031) + t/(0.729+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.041+-0.025) + t/(0.734+-0.003)
# Behaviour for $\Lambda=1.001$: $log_2 N(t) =(-0.079+-0.032) + t/(0.752+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.007+-0.025) + t/(0.732+-0.003)
# Behaviour for $\Lambda=1.001$: $log_2 N(t) =(-0.084+-0.037) + t/(0.759+-0.005)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.251+-0.041) + t/(0.712+-0.005)
# Behaviour for $\Lambda=1.001$: $log_2 N(t) =(0.068+-0.032) + t/(0.754+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.126+-0.035) + t/(0.76+-0.005)
# Behaviour for $\Lambda=1.001$: $log_2 N(t) =(0.015+-0.032) + t/(0.7+-0.004)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_shape_asphericity(control_interactions)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:312: RuntimeWarning: invalid value encountered in scalar divide
#   asph1.append((eigenv1[0]-eigenv1[1])**2 /((eigenv1[0]+eigenv1[1])**2))
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:317: RuntimeWarning: invalid value encountered in scalar divide
#   asph2.append((eigenv2[0]-eigenv2[1])**2 /((eigenv2[0]+eigenv2[1])**2))
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
control_interactions = pfunc.repeat_files(data_loc+"Interacting_colonies\\stress\\Lambda1AND1",5)
Aplot.average_asphericity_time([control_interactions])
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:408: RuntimeWarning: Mean of empty slice
#   avg_Asph1 = np.nanmean(L1_Asph, axis=0)
# C:\Users\lucca\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:2053: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:413: RuntimeWarning: Mean of empty slice
#   avg_Asph2 = np.nanmean(L2_Asph, axis=0)
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_dAsph(control_interactions)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %%
Aplot.average_dasph_time([control_interactions])
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:449: RuntimeWarning: Mean of empty slice
#   avg_dAsph = np.nanmean(L1_dAsph, axis=0)
# Saved average delta asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_dasphericity.pdf

# %%
Aplot.plot_stress_t(control_interactions)
# Out:
# Saved stress over time plot to: C:\Users\lucca\Desktop\GeneratedOutput\stress_colony_time.pdf

# %% [markdown]
# # Another control, see how $\Lambda = 10$ and $\Lambda = 10.001$ interact

# %%
Aplot.plot_cells_grid(control_10)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_shape_asphericity(control_10)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.plot_dAsph(control_10)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %% [markdown]
# Comparison between controls of $\Lambda = 1$ and $\Lambda = 10$ cases.

# %%
Aplot.average_asphericity_time([control_interactions,control_10])
# Out:
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %% [markdown]
# # Different $\Lambda$s interaction
# We start with 1 and 1.5 and go until $\Lambda = 10$

# %%
Aplot.plot_cells_grid(interacting1_5)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_COM_time(interacting1_5)
# Out:
# Saved COM movement plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.average_COM_time([interacting1_5])
# Out:
# Saved average xCOM plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_xCOM.pdf

# %%
Aplot.plot_shape_asphericity(interacting1_5)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.average_asphericity_time([interacting1_5])
# Out:
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_dAsph(interacting1_5)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %%
Aplot.average_dasph_time([interacting1_5])
# Out:
# Saved average delta asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_dasphericity.pdf

# %%
Aplot.plot_growth_rate(interacting1_5)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.034+-0.042) + t/(0.72+-0.007)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.133+-0.045) + t/(0.714+-0.007)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.07+-0.036) + t/(0.725+-0.005)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(-0.057+-0.042) + t/(0.717+-0.006)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.164+-0.034) + t/(0.729+-0.004)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.118+-0.029) + t/(0.757+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.095+-0.033) + t/(0.74+-0.004)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(-0.241+-0.04) + t/(0.748+-0.005)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.008+-0.031) + t/(0.744+-0.004)
# Behaviour for $\Lambda=1.5$: $log_2 N(t) =(0.032+-0.033) + t/(0.751+-0.005)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
#Aplot.plot_Rg_over_time(interacting1_5)

# %%
Aplot.plot_pressure_t(interacting1_5_stress)
# Out:
# Saved pressure plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_time.pdf

# %%
Aplot.plot_pressure_dist(interacting1_5_stress)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND1_5\repeat0\biofilm_00076.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND1_5\repeat1\biofilm_00077.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND1_5\repeat2\biofilm_00071.dat
# Saved pressure vs distance plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_distance.pdf

# %%
Aplot.plot_cells_grid(interacting5)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_COM_time(interacting5)
# Out:
# Saved COM movement plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.average_COM_time([interacting5])
# Out:
# Saved average xCOM plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_xCOM.pdf

# %%
Aplot.plot_growth_rate(interacting5)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.091+-0.038) + t/(0.712+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.187+-0.034) + t/(0.737+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.155+-0.036) + t/(0.743+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.036+-0.034) + t/(0.771+-0.005)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.236+-0.042) + t/(0.709+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.158+-0.04) + t/(0.764+-0.006)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.117+-0.049) + t/(0.79+-0.007)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.101+-0.032) + t/(0.745+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.092+-0.039) + t/(0.711+-0.006)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.181+-0.047) + t/(0.761+-0.008)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_stress_t(interacting5_stress)
# Out:
# Saved stress over time plot to: C:\Users\lucca\Desktop\GeneratedOutput\stress_colony_time.pdf

# %%
Aplot.plot_shape_asphericity(interacting5)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.average_asphericity_time([interacting5])
# Out:
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_dAsph(interacting5)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %%
Aplot.average_dasph_time([interacting5])
# Out:
# Saved average delta asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_dasphericity.pdf

# %%
Aplot.plot_pressure_t(interacting5_stress)
# Out:
# Saved pressure plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_time.pdf

# %%
Aplot.plot_pressure_dist(interacting5_stress)
# Out:
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND5\repeat0\biofilm_00072.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND5\repeat1\biofilm_00074.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND5\repeat2\biofilm_00068.dat
# C:\Users\lucca\Desktop\GeneratedOutput\SimOutput\data\Interacting_colonies\stress\Lambda1AND5\repeat3\biofilm_00073.dat
# Saved pressure vs distance plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_distance.pdf

# %% [markdown]
# # COMPARE GROWTH RATE GR = 5, GR = 3 AND CHECK IMPACT ON INTERACTIONS BETWEEN COLONIES.
# Slower growing colony has a growth rate of 3 microns/h and the faster growing has a growth rate of 5 microns/h

# %%
Aplot.plot_cells_grid(interacting_growth_rate)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_growth_rate(interacting_growth_rate)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.019+-0.031) + t/(1.267+-0.008)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(0.071+-0.03) + t/(1.258+-0.008)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.135+-0.022) + t/(1.259+-0.005)
# Behaviour for $\Lambda=5$: $log_2 N(t) =(-0.235+-0.028) + t/(1.261+-0.006)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_shape_asphericity(interacting_growth_rate)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %% [markdown]
# # Interacting colonies with GR = 5 and $\Lambda = 1$ vs $\Lambda = 10$

# %%
Aplot.plot_cells_grid(interacting10,num_snapshots=6)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_COM_time(interacting10)
# Out:
# Saved COM movement plot to: C:\Users\lucca\Desktop\GeneratedOutput\com_movement.pdf

# %%
Aplot.average_COM_time([interacting10])
# Out:
# Saved average xCOM plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_xCOM.pdf

# %%
Aplot.plot_growth_rate(interacting10)
# Out:
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.038+-0.032) + t/(0.767+-0.004)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.193+-0.035) + t/(0.729+-0.004)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.128+-0.031) + t/(0.766+-0.004)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.018+-0.024) + t/(0.732+-0.003)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.076+-0.029) + t/(0.737+-0.004)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.251+-0.039) + t/(0.749+-0.005)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(-0.274+-0.055) + t/(0.773+-0.009)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.146+-0.04) + t/(0.723+-0.006)
# Behaviour for $\Lambda=1$: $log_2 N(t) =(0.097+-0.033) + t/(0.716+-0.004)
# Behaviour for $\Lambda=10$: $log_2 N(t) =(0.171+-0.035) + t/(0.707+-0.005)
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_shape_asphericity(interacting10)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:314: RuntimeWarning: invalid value encountered in scalar divide
#   asph1.append((eigenv1[0]-eigenv1[1])**2 /((eigenv1[0]+eigenv1[1])**2))
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:319: RuntimeWarning: invalid value encountered in scalar divide
#   asph2.append((eigenv2[0]-eigenv2[1])**2 /((eigenv2[0]+eigenv2[1])**2))
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %%
Aplot.average_asphericity_time([interacting10])
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:408: RuntimeWarning: Mean of empty slice
#   avg_Asph1 = np.nanmean(L1_Asph, axis=0)
# C:\Users\lucca\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:2053: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:413: RuntimeWarning: Mean of empty slice
#   avg_Asph2 = np.nanmean(L2_Asph, axis=0)
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_dAsph(interacting10)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %%
Aplot.average_dasph_time([interacting10])
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:449: RuntimeWarning: Mean of empty slice
#   avg_dAsph = np.nanmean(L1_dAsph, axis=0)
# Saved average delta asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_dasphericity.pdf

# %%
Aplot.plot_pressure_t(interacting10)
# Out:
# Saved pressure plot to: C:\Users\lucca\Desktop\GeneratedOutput\pressure_time.pdf

# %% [markdown]
# # GR3 $\Lambda = 10$ and $\Lambda = 1$

# %%
Aplot.plot_cells_grid(GR_3_L10)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_shape_asphericity(GR_3_L10)
# Out:
# Saved asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\asphericity_colony.pdf

# %% [markdown]
# # COMPARISON behaviour of different $\Lambda$s interacting

# %%
Aplot.average_asphericity_time(interactions_compare_av)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:312: RuntimeWarning: invalid value encountered in scalar divide
#   asph1.append((eigenv1[0]-eigenv1[1])**2 /((eigenv1[0]+eigenv1[1])**2))
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\drag_functions.py:317: RuntimeWarning: invalid value encountered in scalar divide
#   asph2.append((eigenv2[0]-eigenv2[1])**2 /((eigenv2[0]+eigenv2[1])**2))
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:408: RuntimeWarning: Mean of empty slice
#   avg_Asph1 = np.nanmean(L1_Asph, axis=0)
# C:\Users\lucca\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:2053: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:413: RuntimeWarning: Mean of empty slice
#   avg_Asph2 = np.nanmean(L2_Asph, axis=0)
# Saved average asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_asphericity.pdf

# %%
Aplot.plot_dAsph(interactions_compare)
# Out:
# Saved difference in asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\Dasphericity_colony.pdf

# %%
Aplot.average_dasph_time(interactions_compare_av)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:449: RuntimeWarning: Mean of empty slice
#   avg_dAsph = np.nanmean(L1_dAsph, axis=0)
# Saved average delta asphericity plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_dasphericity.pdf

# %%
Aplot.plot_t_doub_Lambda_av(interactions_compare_av+interacting_GR3_av,lines=True)
# Out:
# Saved tdoub vs lambda plot to: C:\Users\lucca\Desktop\GeneratedOutput\tdoub_lambda.pdf

# %%
Aplot.average_COM_time(interactions_compare_av)
# Out:
# Saved average xCOM plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_xCOM.pdf
