# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc

data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"

test_data_120mu=pfunc.repeat_files(data_loc+"InfiniteChannel\\channels_test",2)
test_data_80mu=data_loc+"InfiniteChannel\\channels_test\\repeat2"
test_data_60mu=[data_loc+"InfiniteChannel\\channels_test\\repeat3",data_loc+"InfiniteChannel\\channels_test\\repeat4",data_loc+"InfiniteChannel\\channels_test\\repeat5",data_loc+"InfiniteChannel\\channels_test\\repeat6"]

test_delete = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\test\\channels_delete"
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:641: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
Aplot.plot_channels(test_data_120mu)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
Aplot.plot_channels(test_data_80mu,width=80)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
Aplot.plot_channels(test_data_60mu,width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
Aplot.plot_channels("C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\test\\channels_delete2",width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf
