# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc
import Plot_channels as pch

data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"

test_data_120mu=pfunc.repeat_files(data_loc+"InfiniteChannel\\channels_test",2)
test_data_80mu=data_loc+"InfiniteChannel\\channels_test\\repeat2"
test_data_60mu=[data_loc+"InfiniteChannel\\channels_test\\repeat3",data_loc+"InfiniteChannel\\channels_test\\repeat4",data_loc+"InfiniteChannel\\channels_test\\repeat5",data_loc+"InfiniteChannel\\channels_test\\repeat6",data_loc+"InfiniteChannel\\channels_test\\repeat7"]


microns60 = pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND1_5",2)+pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND5",2)+pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND10",2)
microns60_av = [pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND1_5",2),pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND5",2),pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND10",2)]
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:29: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[Lambdas != 1.0][0]}$: $log_2(R_g) = ({round(params[0],3)}+-{round(err[0],3)}) + t/({round(params[1],3)}+-{round(err[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:36: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda={Lambdas[0]}$: $log_2(R_g) =({round(params_tot[0],3)}+-{round(err_tot[0],3)}) + t/({round(params_tot[1],3)}+-{round(err_tot[1],3)})")
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:46: SyntaxWarning: invalid escape sequence '\L'
#   print(f"Behaviour for $\Lambda=1$: $log_2 N(t) =({round(params_Lambda1[1],3)}+-{round(err_Lambda1[1],3)}) + t/({round(params_Lambda1[0],3)}+-{round(err_Lambda1[0],3)})")
# ...

# %%
pch.plot_channels(test_data_120mu,width=120)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_channels(test_data_80mu,width=80)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_channels(test_data_60mu,width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_exit_y(test_data_60mu[-1])
# Out:
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf

# %%
pch.plot_channels(microns60,width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_exit_y(microns60)
# Out:
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf

# %%
Aplot.plot_counts_over_time(microns60[0])
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.plot_frac_time(microns60)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.average_frac(microns60_av)
# Out:
# Saved average fraction plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_fraction.pdf
