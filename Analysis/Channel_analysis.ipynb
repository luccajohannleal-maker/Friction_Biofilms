# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc
import Plot_channels as pch

data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"

test_data_120mu=pfunc.repeat_files(data_loc+"InfiniteChannel\\channels_test",2)
test_data_80mu=data_loc+"InfiniteChannel\\channels_test\\repeat2"
test_data_60mu=[data_loc+"InfiniteChannel\\channels_test\\repeat3",data_loc+"InfiniteChannel\\channels_test\\repeat4",data_loc+"InfiniteChannel\\channels_test\\repeat5",data_loc+"InfiniteChannel\\channels_test\\repeat6",data_loc+"InfiniteChannel\\channels_test\\repeat7",data_loc+"InfiniteChannel\\channels_test\\repeat8"]


w60L1_5 = pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND1_5",3)
w60L5 = pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND5",4)
w60L10 = pfunc.repeat_files(data_loc+"InfiniteChannel\\60microns\\Lambdas1AND10",3)

microns60 = w60L1_5 + w60L5 + w60L10
microns60_av = [w60L1_5,w60L5,w60L10]

w40L1_5 = pfunc.repeat_files(data_loc+"InfiniteChannel\\40microns\\Lambdas1AND1_5",1)
w40L5 = pfunc.repeat_files(data_loc+"InfiniteChannel\\40microns\\Lambdas1AND5",1)
w40L10 = pfunc.repeat_files(data_loc+"InfiniteChannel\\40microns\\Lambdas1AND10",1)

microns40 = w40L1_5 + w40L5 + w40L10
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:154: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:182: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:210: SyntaxWarning: invalid escape sequence '\L'
#   legend_elements = legend_elements+ [ mpatches.Patch(facecolor=dfunc.colour_Lambda(Lambda),label='$\Lambda =$'+str(Lambda)) ]
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:264: SyntaxWarning: invalid escape sequence '\L'
# ...

# %%
pch.plot_channels(test_data_120mu,width=120)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_channels(test_data_80mu,width=80)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_channels(test_data_60mu,width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %% [markdown]
# # Channel height (width) = 60 microns

# %%
pch.plot_channels(microns60,width=60)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_exit_y(w60L10)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Plot_channels.py:102: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf

# %%
pch.plot_exit_y(w60L5)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:1008: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf

# %%
pch.plot_exit_y(w60L1_5)
# Out:
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf

# %%
Aplot.plot_counts_over_time(microns60)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.plot_frac_time(microns60)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.plot_frac_time(w60L10)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.average_frac([w60L10])
# Out:
# Saved average fraction plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_fraction.pdf

# %%
pch.average_frac(microns60_av)
# Out:
# Saved average fraction plot to: C:\Users\lucca\Desktop\GeneratedOutput\average_fraction.pdf

# %% [markdown]
# # Channel height = 40 microns

# %%
pch.plot_channels(microns40, width=40)
# Out:
# Saved channel snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\channel_snapshot.pdf

# %%
pch.plot_frac_time(microns40)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
pch.plot_exit_y(microns40)
# Out:
# Saved channel y exit to: C:\Users\lucca\Desktop\GeneratedOutput\channel_y_exit.pdf
