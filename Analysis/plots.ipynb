# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import Automated_Plotting as Aplot
import plotting_functions as pfunc

data_loc = "C:\\Users\\lucca\\Desktop\\GeneratedOutput\\SimOutput\\data\\"
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\Automated_Plotting.py:193: SyntaxWarning: invalid escape sequence '\k'
#   plt.ylabel("Relative shape anisotropy $\kappa$")
# Estimated doubling time for Lambda=1: 0.7237936487377397+-0.00040093065312235456
# Estimated doubling time for Lambda=1.5: 0.7284382759099787+-0.00044845841708374254

# %%
file = data_loc+"FreeGrow\\Lambda1\\repeat0"
Aplot.plot_growth_rate(file)
# Out:
# Estimated doubling time for Lambda=1: 0.7342168715451854+-0.00027271714102176936
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_counts_over_time(file)
# Out:
# Saved cell count plot to: C:\Users\lucca\Desktop\GeneratedOutput\counts.pdf

# %%
Aplot.plot_cells_grid(file)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_Rg_over_time(file)
# Out:
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
Aplot.plot_shape_anisotropy(file)
# Out:
# C:\Users\lucca\Desktop\Friction_Biofilms\Analysis\plotting_functions.py:64: RuntimeWarning: invalid value encountered in scalar divide
#   shape_tot1.append(1.5*(Rg_tot_eig[i,0]**4+Rg_tot_eig[i,1]**4)/((Rg_tot_eig[i,0]**2+Rg_tot_eig[i,1]**2)**2) - 0.5)
# Saved anisotropy plot to: C:\Users\lucca\Desktop\GeneratedOutput\anisotropy_colony.pdf

# %%
files = [data_loc+"FreeGrow\\Lambda0_8\\repeat0",data_loc+"FreeGrow\\Lambda1\\repeat2",data_loc+"FreeGrow\\Lambda1_5\\repeat0",data_loc+"FreeGrow\\Lambda5\\repeat0",data_loc+"FreeGrow\\Lambda10\\repeat0"]
Aplot.plot_growth_rate(files)
# Out:
# Estimated doubling time for Lambda=0.8: 0.7598782307089372+-0.00033186702252246074
# Estimated doubling time for Lambda=1: 0.7358433592165088+-0.00018457300330136967
# Estimated doubling time for Lambda=1.5: 0.7459999368499501+-0.000243456651866329
# Estimated doubling time for Lambda=5: 0.787505262008189+-0.0006079161098287106
# Estimated doubling time for Lambda=10: 0.7266560723034629+-0.0007010779611997186
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_Rg_over_time(files)
# Out:
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
Aplot.plot_cells_grid(files)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_shape_anisotropy(files)
# Out:
# Saved anisotropy plot to: C:\Users\lucca\Desktop\GeneratedOutput\anisotropy_colony.pdf

# %%
repeats_lambda1 = pfunc.repeat_files(data_loc+"FreeGrow\\Lambda1",5)
Aplot.plot_growth_rate(repeats_lambda1)
# Out:
# Estimated doubling time for Lambda=1: 0.7342168715451854+-0.00027271714102176936
# Estimated doubling time for Lambda=1: 0.7430317306734825+-0.0003079507486623069
# Estimated doubling time for Lambda=1: 0.7358433592165088+-0.00018457300330136967
# Estimated doubling time for Lambda=1: 0.7173288466193208+-0.00028346347217412794
# Estimated doubling time for Lambda=1: 0.6997618332653707+-0.0005925521166730021
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
#Interacting colonies
interacting_files = pfunc.repeat_files(data_loc+"Interacting_colonies",2)
interacting_files.append(data_loc+"Interacting_colonies\\Lambda1AND5\\repeat0")
Aplot.plot_cells_grid(interacting_files)
# Out:
# Saved snapshot grid to: C:\Users\lucca\Desktop\GeneratedOutput\snapshots.pdf

# %%
Aplot.plot_shape_anisotropy(interacting_files)
# Out:
# Saved anisotropy plot to: C:\Users\lucca\Desktop\GeneratedOutput\anisotropy_colony.pdf

# %%
Aplot.plot_growth_rate(interacting_files)
# Out:
# Estimated doubling time for Lambda=1: 0.7251548963810825+-0.00045983815993084343
# Estimated doubling time for Lambda=1.5: 0.7082919959415755+-0.0007157880667926352
# Estimated doubling time for Lambda=1: 0.7237936487377397+-0.00040093065312235456
# Estimated doubling time for Lambda=1.5: 0.7284382759099787+-0.00044845841708374254
# Estimated doubling time for Lambda=1: 0.7073275405641677+-0.0005581642532033546
# Estimated doubling time for Lambda=5: 0.7760042612782955+-0.0005055610687805091
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf

# %%
Aplot.plot_Rg_over_time(interacting_files)
# Out:
# Saved Rg plot to: C:\Users\lucca\Desktop\GeneratedOutput\Rg.pdf

# %%
#growth rate tests
GR_files = [data_loc+"GR_vary\\GR1",data_loc+"GR_vary\\GR3",data_loc+"FreeGrow\\Lambda10\\repeat0"]
Aplot.plot_growth_rate(GR_files)
# Out:
# Estimated doubling time for Lambda=10: 4.604383617661268+-0.1797975555434351
# Estimated doubling time for Lambda=10: 1.2443655209193292+-0.0007746268072392099
# Estimated doubling time for Lambda=10: 0.7266560723034629+-0.0007010779611997186
# Saved growth rate plot to: C:\Users\lucca\Desktop\GeneratedOutput\growth_rate_GR.pdf
